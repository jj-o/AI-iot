# %% [markdown]
# auto : 입력과 출력이 같음

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

# %%
# MNIST 로딩 (라벨은 필요없기 때문에 버림)
(train_x, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# 데이터 정규화
train_x = train_x.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
train_x = np.reshape(train_x, (len(train_x), 784))
x_test = np.reshape(x_test, (len(x_test), 784))

# %%
# Noise가 추가된 데이터 확인
n = 10
plt.figure(figsize=(20, 2))
for i in range(1,n):
    ax = plt.subplot(1, n, i)
    plt.imshow(train_x[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# 모형 구성
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=784))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(784, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy')


# 모형 학습
model.fit(train_x, train_x, epochs=100, batch_size=256)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 17ms/step - loss: 0.2462
# Epoch 2/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1504
# Epoch 3/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1307
# Epoch 4/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1208
# Epoch 5/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1148
# Epoch 6/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1111
# Epoch 7/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1077
# Epoch 8/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1050
# Epoch 9/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1028
# Epoch 10/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1009
# Epoch 11/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0994
# Epoch 12/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0981
# Epoch 13/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0970
# Epoch 14/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0960
# Epoch 15/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0953
# Epoch 16/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0945
# Epoch 17/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0938
# Epoch 18/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0932
# Epoch 19/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0927
# Epoch 20/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0922
# Epoch 21/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0918
# Epoch 22/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0914
# Epoch 23/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0909
# Epoch 24/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0903
# Epoch 25/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0899
# Epoch 26/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0894
# Epoch 27/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0890
# Epoch 28/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0887
# Epoch 29/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0883
# Epoch 30/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0880
# Epoch 31/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0876
# Epoch 32/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0872
# Epoch 33/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0869
# Epoch 34/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0866
# Epoch 35/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0864
# Epoch 36/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0862
# Epoch 37/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0860
# Epoch 38/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0858
# Epoch 39/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0856
# Epoch 40/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0855
# Epoch 41/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0854
# Epoch 42/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0852
# Epoch 43/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0851
# Epoch 44/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0850
# Epoch 45/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0849
# Epoch 46/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0848
# Epoch 47/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0847
# Epoch 48/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0847
# Epoch 49/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0846
# Epoch 50/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0845
# Epoch 51/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0844
# Epoch 52/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0843
# Epoch 53/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0842
# Epoch 54/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0841
# Epoch 55/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0841
# Epoch 56/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0840
# Epoch 57/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0839
# Epoch 58/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0838
# Epoch 59/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0838
# Epoch 60/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0838
# Epoch 61/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0836
# Epoch 62/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0836
# Epoch 63/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0836
# Epoch 64/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0835
# Epoch 65/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0834
# Epoch 66/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0834
# Epoch 67/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0834
# Epoch 68/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0833
# Epoch 69/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0832
# Epoch 70/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0832
# Epoch 71/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0831
# Epoch 72/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0831
# Epoch 73/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0830
# Epoch 74/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0830
# Epoch 75/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0829
# Epoch 76/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0829
# Epoch 77/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0828
# Epoch 78/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0828
# Epoch 79/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0828
# Epoch 80/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0827
# Epoch 81/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0827
# Epoch 82/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0826
# Epoch 83/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0826
# Epoch 84/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0826
# Epoch 85/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0825
# Epoch 86/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0825
# Epoch 87/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0825
# Epoch 88/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0824
# Epoch 89/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0824
# Epoch 90/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0824
# Epoch 91/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0823
# Epoch 92/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0823
# Epoch 93/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0823
# Epoch 94/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822
# Epoch 95/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822
# Epoch 96/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822
# Epoch 97/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822
# Epoch 98/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0821
# Epoch 99/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0821
# Epoch 100/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0821

# %%
reconstruted = model.predict(x_test)

n = 10
plt.figure(figsize=(20, 6))
for i in range(1,n):
    # 원본 표시
    ax = plt.subplot(3, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


    # 출력된 것
    ax = plt.subplot(3, n, i + n)
    plt.imshow(reconstruted[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()
