# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input, Reshape

import time

# %%
(raw_train_x, raw_train_y), (raw_test_x, raw_test_y) = tf.keras.datasets.mnist.load_data()

train_x = raw_train_x/255.
test_x = raw_test_x/255.

train_y = raw_train_y
test_y = raw_test_y
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
model = keras.Sequential()
model.add(Input((28,28)))
model.add(Reshape((28,28,1))) # ADDED
model.add(Conv2D(32, (3, 3), padding='same')) # ADDED
model.add(MaxPooling2D((2, 2))) # ADDED
model.add(Conv2D(64, (3, 3), padding='same')) # ADDED
model.add(MaxPooling2D((2, 2))) # ADDED
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()


model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=128)


loss, acc = model.evaluate(test_x, test_y)
print("loss=",loss)
print("acc=",acc)

y_ = model.predict(test_x)
predicted = np.argmax(y_, axis=1)

print(predicted)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_2 (Reshape)         (None, 28, 28, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 32)        320
#
#  batch_normalization (BatchN  (None, 28, 28, 32)       128
#  ormalization)
#
#  dropout (Dropout)           (None, 28, 28, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 28, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 14, 14, 32)       128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_6 (Dense)             (None, 10)                31370
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dense_8 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 69,670
# Trainable params: 69,286
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 5s 9ms/step - loss: 0.8424 - accuracy: 0.7189
# Epoch 2/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3882 - accuracy: 0.8830
# Epoch 3/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3033 - accuracy: 0.9096
# Epoch 4/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2623 - accuracy: 0.9208
# Epoch 5/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2275 - accuracy: 0.9314
# Epoch 6/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2072 - accuracy: 0.9373
# Epoch 7/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1821 - accuracy: 0.9456
# Epoch 8/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1699 - accuracy: 0.9476
# Epoch 9/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1525 - accuracy: 0.9532
# Epoch 10/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1437 - accuracy: 0.9556
# Epoch 11/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1358 - accuracy: 0.9577
# Epoch 12/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1271 - accuracy: 0.9608
# Epoch 13/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1257 - accuracy: 0.9617
# Epoch 14/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1178 - accuracy: 0.9632
# Epoch 15/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1135 - accuracy: 0.9642
# Epoch 16/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1090 - accuracy: 0.9658
# Epoch 17/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1033 - accuracy: 0.9667
# Epoch 18/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1000 - accuracy: 0.9675
# Epoch 19/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0976 - accuracy: 0.9689
# Epoch 20/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0929 - accuracy: 0.9701
# Epoch 21/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0890 - accuracy: 0.9723
# Epoch 22/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0868 - accuracy: 0.9723
# Epoch 23/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0866 - accuracy: 0.9723
# Epoch 24/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0836 - accuracy: 0.9728
# Epoch 25/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0804 - accuracy: 0.9736
# Epoch 26/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0801 - accuracy: 0.9747
# Epoch 27/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0784 - accuracy: 0.9748
# Epoch 28/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0757 - accuracy: 0.9756
# Epoch 29/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0733 - accuracy: 0.9761
# Epoch 30/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0726 - accuracy: 0.9768
# Epoch 31/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0695 - accuracy: 0.9769
# Epoch 32/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0694 - accuracy: 0.9780
# Epoch 33/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0680 - accuracy: 0.9778
# Epoch 34/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0677 - accuracy: 0.9778
# Epoch 35/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0645 - accuracy: 0.9791
# Epoch 36/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0620 - accuracy: 0.9791
# Epoch 37/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0615 - accuracy: 0.9799
# Epoch 38/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0598 - accuracy: 0.9800
# Epoch 39/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0599 - accuracy: 0.9801
# Epoch 40/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0577 - accuracy: 0.9807
# Epoch 41/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0552 - accuracy: 0.9815
# Epoch 42/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0576 - accuracy: 0.9809
# Epoch 43/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0570 - accuracy: 0.9813
# Epoch 44/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0536 - accuracy: 0.9829
# Epoch 45/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0517 - accuracy: 0.9830
# Epoch 46/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0565 - accuracy: 0.9813
# Epoch 47/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0540 - accuracy: 0.9820
# Epoch 48/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0525 - accuracy: 0.9828
# Epoch 49/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0502 - accuracy: 0.9834
# Epoch 50/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0502 - accuracy: 0.9833
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1271 - accuracy: 0.9687
# loss= 0.12710034847259521
# acc= 0.9686999917030334
# [7 2 1 ... 4 5 6]

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input, Reshape

import time

(raw_train_x, raw_train_y), (raw_test_x, raw_test_y) = tf.keras.datasets.mnist.load_data()

train_x = raw_train_x/255.
test_x = raw_test_x/255.

train_y = raw_train_y
test_y = raw_test_y

model = keras.Sequential()
model.add(Input((28,28)))
model.add(Reshape((28,28,1)))
model.add(Conv2D(32, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()


model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=128)


loss, acc = model.evaluate(test_x, test_y)
print("loss=",loss)
print("acc=",acc)

y_ = model.predict(test_x)
predicted = np.argmax(y_, axis=1)

print(predicted)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 28, 28, 1)         0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_3 (Dense)             (None, 10)                16010
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 35,046
# Trainable params: 35,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 469/469 [==============================] - 38s 80ms/step - loss: 0.4479 - accuracy: 0.8563
# Epoch 2/5
# 469/469 [==============================] - 37s 80ms/step - loss: 0.1377 - accuracy: 0.9603
# Epoch 3/5
# 469/469 [==============================] - 37s 79ms/step - loss: 0.1005 - accuracy: 0.9709
# Epoch 4/5
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0824 - accuracy: 0.9756
# Epoch 5/5
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0704 - accuracy: 0.9795
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0632 - accuracy: 0.9804
# loss= 0.06323625147342682
# acc= 0.980400025844574
# [7 2 1 ... 4 5 6]
